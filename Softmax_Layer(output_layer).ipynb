# %% [markdown]
# <a href="https://colab.research.google.com/github/LakshyaaVK/Deep-learning/blob/main/Softmax_Layer(output_layer).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from math import exp

# %%
z = [-1.0, 1.0, 5.0]

# %%
exp(z[0])
# Out:
# 0.36787944117144233

# %%
exp(z[1])
# Out:
# 2.718281828459045

# %%
exp(z[2])
# Out:
# 148.4131591025766

# %%
total = exp(z[0]) + exp(z[1]) + exp(z[2])

# %%
total
# Out:
# 151.49932037220708

# %%
exp(z[0])/total
# Out:
# 0.0024282580295913376

# %%
exp(z[1])/total
# Out:
# 0.017942534803329194

# %%
exp(z[2])/total
# Out:
# 0.9796292071670795
